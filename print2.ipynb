# %%
x="python"
y="is"
z="awesome"
print(x,y,z)
# Out:
# python is awesome

# %%
print(x+y+z)
# Out:
# pythonisawesome

# %%
x=5
y=10
print(x+y)
# Out:
# 15

# %%
x=5
y="john"
print(x,y)
# Out:
# 5 john
