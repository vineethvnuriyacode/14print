# %%
print(1)
# Out:
# 1

# %%
 print("a")
# Out:
# a

# %%
a=1
print(1)
# Out:
# 1

# %%
print("a"+b"b")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print("a"+b"b")
#
# TypeError: can only concatenate str (not "bytes") to str

# %%
"a"+"b"
# Out:
# 'ab'

# %%
'a'*6
# Out:
# 'aaaaaa'

# %%
print('a'+'b')
# Out:
# ab

# %%
 a=5
print(a)
b=3.14
print(b)
# Out:
# 5
# 3.14

# %%
print(42.0)
# Out:
# 42.0
